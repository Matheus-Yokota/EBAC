# %% [markdown]
# # Árvores de regressão - exercícios 01
#
# Nesta bateria de exercícios, vamos botar em prática o que aprendemos com a base de dados imobiliários de Boston, que pode ser baixada do módulo ```datasets``` do scikitlearn. Essa base de dados possui uma linha por cidade, o objetivo é prever, ou fornecer uma estimativa de ```MEDV```, ou o valor mediano de casas ocupadas pelo dono, dadas as demais variáveis usadas como explicativas.
#
# A descrição das variáveis está abaixo:

# %% [markdown]
# | Variavel | Descrição|
# |-|-|
# |CRIM| taxa de crimes per-cápita da cidade |
# |ZN| proporção de terrenos residenciais zoneados para lotes com mais de 25.000 pés quadrados. |
# |INDUS| proporção de acres de negócios não varejistas por cidade |
# |CHAS |vale 1 se o terreno faz fronteira com o *Charles River*; 0 caso contrário |
# |NOX| Concentração de óxido nítrico (em partes por 10 milhões) |
# |RM| número médio de quartos por habitação |
# |AGE| proporção de unidades ocupadas pelo proprietário construídas antes de 1940 |
# |DIS| distâncias ponderadas até cinco centros de empregos de Boston |
# |RAD| índice de acessibilidade a rodovias radiais |
# |TAX| taxa de imposto sobre a propriedade de valor total por \\$10,000 |
# |PTRATIO| razão pupilo-professor da cidade |
# |B| $ 1000 (Bk - 0,63) ^ 2 $ onde Bk é a proporção de negros por cidade |
# |LSTAT| \%status inferior da população |
# |MEDV| (variável resposta) Valor mediano das casas ocupadas pelo proprietário em US $ 1.000|

# %%
# Importando as bibliotecas e a base de dados

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import train_test_split

caminho = r"C:\Users\kenji\OneDrive\Documentos\EBAC\Ciêntista de dados\Módulo 11\Dataset_Boston.csv"
boston = pd.read_csv(caminho, sep=';')

X = boston.drop(columns=['medv']).copy()
y = boston[['medv']]

# %%
X.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2   4.090    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  49.671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  49.671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  60.622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  60.622    3  222     18.7
#
#         b  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
y.head()
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %% [markdown]
# ### 1. Certifique-se de que esta base está no formato adequado para o scikitlearn.
# ok, essa tarefa é tão fácil que você vai até desconfiar. Mas é preciso ter confiança sobre os dados que se usa ;)

# %%
# Usando o info é possivel dar uma primeira vizualização no banco de dados.
# Pode-se verificar que na base de dados não existem dados vazios (NaN), então não é nesserário utilizar o dropna
# Verifica-se também que não existem variáveis categóricas, descartando a necessidade de usar o pd.get_dummy

boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
# Usando o drop_duplicate verifica-se que n]ao existem linhas repetidas

boston.drop_duplicates()
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2   4.090    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  49.671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  49.671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  60.622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  60.622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  24.786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  22.875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  21.675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  23.889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8   2.505    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# ### 2.  Visualize a matriz de correlação, e veja se aparentemente você encontra alguma variável com potencial preditivo interessante.

# %%
# Usando o corr é possível verificar a existencia de alguma correlação entre as variáveis
# Quanto mais próximo de 1 ou -1 maior a correlação entre as variáveis

correlacao = boston.corr()

# %%
correlacao[correlacao > 0.7]
# Out:
#              crim   zn     indus  chas       nox   rm      age  dis       rad  \
# crim     1.000000  NaN       NaN   NaN       NaN  NaN      NaN  NaN  0.767352
# zn            NaN  1.0       NaN   NaN       NaN  NaN      NaN  NaN       NaN
# indus         NaN  NaN  1.000000   NaN  0.763651  NaN      NaN  NaN       NaN
# chas          NaN  NaN       NaN   1.0       NaN  NaN      NaN  NaN       NaN
# nox           NaN  NaN  0.763651   NaN  1.000000  NaN  0.73147  NaN       NaN
# rm            NaN  NaN       NaN   NaN       NaN  1.0      NaN  NaN       NaN
# age           NaN  NaN       NaN   NaN  0.731470  NaN  1.00000  NaN       NaN
# dis           NaN  NaN       NaN   NaN       NaN  NaN      NaN  1.0       NaN
# rad      0.767352  NaN       NaN   NaN       NaN  NaN      NaN  NaN  1.000000
# tax      0.727160  NaN  0.720760   NaN       NaN  NaN      NaN  NaN  0.910228
# ptratio       NaN  NaN       NaN   NaN       NaN  NaN      NaN  NaN       NaN
# ...

# %%
correlacao[correlacao < -0.7]

# Aparentemente a variável resposta, medv, apresenta uma correlação negativa com a variável lstat
# Out:
#          crim  zn  indus  chas  nox  rm  age  dis  rad  tax  ptratio   b  \
# crim      NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# zn        NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# indus     NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# chas      NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# nox       NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# rm        NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# age       NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# dis       NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# rad       NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# tax       NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# ptratio   NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# b         NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN
# ...

# %% [markdown]
# ### 3. Separe os dados em validação e teste

# %%
# Separando os dados em validação e teste

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2360873)

# %% [markdown]
# ### 4. Treine duas árvores, uma com profundidade máxima = 8, outra com profundidade máxima = 2.

# %%
# Fit regression model

regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=8)

regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8)

# %% [markdown]
# ### 5. Calcule o MSE de cada uma das árvores do item anterior para a base de treinamento e para a base de testes.

# %%
# mse1 = mean_squared_error(y_test, regr_1.predict(X_test))
mse1 = regr_1.score(X_train, y_train)
mse2 = regr_2.score(X_train, y_train)

template = "O MSE da árvore com profundidade={0} é: {1:.2f}"

print(template.format(regr_1.get_depth(),mse1).replace(".",","))
print(template.format(regr_2.get_depth(),mse2).replace(".",","))
# Out:
# O MSE da árvore com profundidade=2 é: 0,71
# O MSE da árvore com profundidade=8 é: 0,98

# %% [markdown]
# ### 6. Com base nos resultados do item anterior, qual árvore te parece mais adequada?

# %% [markdown]
# Com base nos dados obtidos do item anterior a árvore com profundidade igual à 8 aparenta ser a mais adequada, dado que resultou em um valor de R² muito próximo de 1.

# %% [markdown]
# ### 7. Faça uma visualização gráfica dessa árvore. Vamos discutir importância de variável mais adiante, mas veja a sua árvore, e pense um pouco: qual variável te parece mais "importante" na árvore?

# %%
import graphviz
# DOT data
dot_data = tree.export_graphviz(regr_2, out_file=None, 
                                feature_names=X.columns,
                                filled=True)

# Draw graph
graph = graphviz.Source(dot_data, format="png") 
graph

# Aparentemente a variável mais importante na árvore é o número médio de quartos rm. Dado que ele é o nó principal da árvore.
